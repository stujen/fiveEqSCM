# %%
## Get dependencies ##

import numpy as np
import string
import math
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sn
from UnFaIR import *
import scipy as sp
import pickle

# %%
s='85'

RCP_forc = pd.read_csv('./Conc_fit_data/RCP'+s+'_MIDYEAR_RADFORCING.csv',skiprows=58,index_col=0)

otherforc = RCP_forc.TOTAL_INCLVOLCANIC_RF.loc[:2012].values - RCP_forc.CO2CH4N2O_RF.loc[:2012].values

BE_E = pd.read_csv('Best_estimate_emissions_for_UnFaIR.csv',index_col=0)

# %%
SLR_model(UnFaIR(BE_E,otherforc)).plot()
