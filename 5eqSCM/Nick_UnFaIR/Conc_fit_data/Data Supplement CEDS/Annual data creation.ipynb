# %%
import numpy as np
import pandas as pd

# %%
country = pd.read_csv('CO2_CEDS_emissions_by_country_v2017_05_18.csv')

# %%
glob = country.T.iloc[3:].set_index(np.arange(1750,2015,1)).sum(axis=1)/
# Out:
#       em country units     X1750     X1751     X1752     X1753     X1754  \
# 0    CO2     abw   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    CO2     afg   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    CO2     ago   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    CO2     alb   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    CO2     are   ktC  3.062065  3.077376  3.092686  3.107996  3.123307
# 5    CO2     arg   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 6    CO2     arm   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 7    CO2     asm   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 8    CO2     atg   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 9    CO2     aus   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 10   CO2     aut   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# 11   CO2     aze   ktC  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
glob = ext_glob.append(glob)

# %%
(glob/1000).to_csv('CEDS_CO2_global_emissions_1850_2014.csv')
